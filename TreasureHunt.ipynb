# %%
import numpy as np
import pandas as pd
import time

np.random.seed(2)  # reproducible

# %%
N_STATES = 6   # the length of the 1 dimensional world
ACTIONS = ['left', 'right']     # available actions

EPSILON = 0.9   # greedy policy
ALPHA = 0.1     # learning rate
GAMMA = 0.9    # discount factor

MAX_EPISODES = 13   # maximum episodes

FRESH_TIME = 0.3    # refresh/pause time for one move used in time.sleep

# %%
def build_q_table(n_states, actions):
    table = pd.DataFrame(
        np.zeros((n_states, len(actions))),     # q_table initial values
        columns=actions,    # actions's name
    )
    #print(table)    # show table
    return table

# %%
def choose_action(state, q_table):
    # This is how to choose an action
    state_actions = q_table.iloc[state, :]

    if (np.random.uniform() > EPSILON) or ((state_actions == 0).all()):  # act non-greedy or state-action have no value
        action_name = np.random.choice(ACTIONS) #Exploration
    else:   # act greedy
        action_name = state_actions.idxmax()    # replace argmax to idxmax as argmax means a different function in newer version of pandas

    return action_name

# %%
#similar to env.step() ---> accepting state and action and returning reward and next state
def get_env_feedback(S, A):
    # This is how agent will interact with the environment
    if A == 'right':    # move right
        if S == N_STATES - 2:   # terminate
            S_ = 'terminal'
            R = 1
        else:
            S_ = S + 1
            R = 0
    else:   # move left
        R = 0
        if S == 0:
            S_ = S  # reach the wall
        else:
            S_ = S - 1
    return S_, R

# %%
def update_env(S, episode, step_counter):#env.render()
    # This is how environment be updated
    env_list = ['-']*(N_STATES-1) + ['T']   # '---------T' our environment
    if S == 'terminal':
        interaction = 'Episode %s: total_steps = %s' % (episode+1, step_counter)
        print('\r{}'.format(interaction), end='')
        time.sleep(2)
        print('\r                                ', end='')
    else:
        env_list[S] = 'o'
        interaction = ''.join(env_list)
        print('\r{}'.format(interaction), end='')
        time.sleep(FRESH_TIME)

# %%
def rl():
    # main part of RL loop
    q_table = build_q_table(N_STATES, ACTIONS)
    for episode in range(MAX_EPISODES):
        step_counter = 0
        S = 0
        is_terminated = False
        update_env(S, episode, step_counter)
        while not is_terminated:

            A = choose_action(S, q_table)
            S_, R = get_env_feedback(S, A)  # take action & get next state and reward
            q_predict = q_table.loc[S, A]
            if S_ != 'terminal':
                q_target = R + GAMMA * q_table.iloc[S_, :].max()   # next state is not terminal
            else:
                q_target = R     # next state is terminal
                is_terminated = True    # terminate this episode

            q_table.loc[S, A] += ALPHA * (q_target - q_predict)  # update
            S = S_  # move to next state

            update_env(S, episode, step_counter+1)
            step_counter += 1
    return q_table

# %%
q_table = rl()
print('\r\nQ-table:\n')
print(q_table)
# Out:
#
# Q-table:
#
#        left     right
# 0  0.000000  0.004320
# 1  0.000000  0.025005
# 2  0.000030  0.111241
# 3  0.000000  0.368750
# 4  0.027621  0.745813
# 5  0.000000  0.000000

# %%
#RL Deploy Code
state = 0 
iterations_no = 100 
for i in range(iterations_no):     
    randomAction = ACTIONS[state]     
    retnVal = get_env_feedback(state, randomAction)     
    print("return Value ", retnVal)     
    print( "iteration {} and action {}".format(i+1,                                       
      randomAction))     
    time.sleep(2)     
    state = retnVal[0]     
    if retnVal == state:         
        break;
# Out:
# return Value  (0, 0)
# iteration 1 and action left
# return Value  (0, 0)
# iteration 2 and action left
# return Value  (0, 0)
# iteration 3 and action left
# return Value  (0, 0)
# iteration 4 and action left
# return Value  (0, 0)
# iteration 5 and action left
# return Value  (0, 0)
# iteration 6 and action left
# return Value  (0, 0)
# iteration 7 and action left
# return Value  (0, 0)
# iteration 8 and action left
# return Value  (0, 0)
# iteration 9 and action left
# return Value  (0, 0)
# iteration 10 and action left
# return Value  (0, 0)
# iteration 11 and action left
# return Value  (0, 0)
# iteration 12 and action left
# return Value  (0, 0)
# iteration 13 and action left
# return Value  (0, 0)
# iteration 14 and action left
# return Value  (0, 0)
# iteration 15 and action left
# return Value  (0, 0)
# iteration 16 and action left
# return Value  (0, 0)
# iteration 17 and action left
# return Value  (0, 0)
# iteration 18 and action left
# return Value  (0, 0)
# iteration 19 and action left
# return Value  (0, 0)
# iteration 20 and action left
# return Value  (0, 0)
# iteration 21 and action left
# return Value  (0, 0)
# iteration 22 and action left
# return Value  (0, 0)
# iteration 23 and action left
# return Value  (0, 0)
# iteration 24 and action left
# return Value  (0, 0)
# iteration 25 and action left
# return Value  (0, 0)
# iteration 26 and action left
# return Value  (0, 0)
# iteration 27 and action left
# return Value  (0, 0)
# iteration 28 and action left
# return Value  (0, 0)
# iteration 29 and action left
# return Value  (0, 0)
# iteration 30 and action left
# return Value  (0, 0)
# iteration 31 and action left
# return Value  (0, 0)
# iteration 32 and action left
# return Value  (0, 0)
# iteration 33 and action left
# return Value  (0, 0)
# iteration 34 and action left
# return Value  (0, 0)
# iteration 35 and action left
# return Value  (0, 0)
# iteration 36 and action left
# return Value  (0, 0)
# iteration 37 and action left
# return Value  (0, 0)
# iteration 38 and action left
# return Value  (0, 0)
# iteration 39 and action left
# return Value  (0, 0)
# iteration 40 and action left
# return Value  (0, 0)
# iteration 41 and action left
# return Value  (0, 0)
# iteration 42 and action left
# return Value  (0, 0)
# iteration 43 and action left
# return Value  (0, 0)
# iteration 44 and action left
# return Value  (0, 0)
# iteration 45 and action left
# return Value  (0, 0)
# iteration 46 and action left
# return Value  (0, 0)
# iteration 47 and action left
# return Value  (0, 0)
# iteration 48 and action left
# return Value  (0, 0)
# iteration 49 and action left
# return Value  (0, 0)
# iteration 50 and action left
# return Value  (0, 0)
# iteration 51 and action left
# return Value  (0, 0)
# iteration 52 and action left
# return Value  (0, 0)
# iteration 53 and action left
# return Value  (0, 0)
# iteration 54 and action left
# return Value  (0, 0)
# iteration 55 and action left
# return Value  (0, 0)
# iteration 56 and action left
# return Value  (0, 0)
# iteration 57 and action left
# return Value  (0, 0)
# iteration 58 and action left
# return Value  (0, 0)
# iteration 59 and action left
# return Value  (0, 0)
# iteration 60 and action left
# return Value  (0, 0)
# iteration 61 and action left
# return Value  (0, 0)
# iteration 62 and action left
# return Value  (0, 0)
# iteration 63 and action left
# return Value  (0, 0)
# iteration 64 and action left
# return Value  (0, 0)
# iteration 65 and action left
# return Value  (0, 0)
# iteration 66 and action left
# return Value  (0, 0)
# iteration 67 and action left
# return Value  (0, 0)
# iteration 68 and action left
# return Value  (0, 0)
# iteration 69 and action left
# return Value  (0, 0)
# iteration 70 and action left
# return Value  (0, 0)
# iteration 71 and action left
# return Value  (0, 0)
# iteration 72 and action left
# return Value  (0, 0)
# iteration 73 and action left
# return Value  (0, 0)
# iteration 74 and action left
# return Value  (0, 0)
# iteration 75 and action left
# return Value  (0, 0)
# iteration 76 and action left
# return Value  (0, 0)
# iteration 77 and action left
# return Value  (0, 0)
# iteration 78 and action left
# return Value  (0, 0)
# iteration 79 and action left
# return Value  (0, 0)
# iteration 80 and action left
# return Value  (0, 0)
# iteration 81 and action left
# return Value  (0, 0)
# iteration 82 and action left
# return Value  (0, 0)
# iteration 83 and action left
# return Value  (0, 0)
# iteration 84 and action left
# return Value  (0, 0)
# iteration 85 and action left
# return Value  (0, 0)
# iteration 86 and action left
# return Value  (0, 0)
# iteration 87 and action left
# return Value  (0, 0)
# iteration 88 and action left
# return Value  (0, 0)
# iteration 89 and action left
# return Value  (0, 0)
# iteration 90 and action left
# return Value  (0, 0)
# iteration 91 and action left
# return Value  (0, 0)
# iteration 92 and action left
# return Value  (0, 0)
# iteration 93 and action left
# return Value  (0, 0)
# iteration 94 and action left
# return Value  (0, 0)
# iteration 95 and action left
# return Value  (0, 0)
# iteration 96 and action left
# return Value  (0, 0)
# iteration 97 and action left
# return Value  (0, 0)
# iteration 98 and action left
# return Value  (0, 0)
# iteration 99 and action left
# return Value  (0, 0)
# iteration 100 and action left
